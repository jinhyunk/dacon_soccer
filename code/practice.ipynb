# %%
import os
import pandas as pd

tdp = '../data/open_track1/test'

filenames = os.listdir(tdp)

for game_id in filenames:
    game_data = os.listdir(tdp + '/' + game_id)
    for idx, file in enumerate(game_data):
        file_path = tdp + '/' + game_id + '/' + file
        
        if idx == 0:
            tot = pd.read_csv(file_path)
        
        tot = pd.concat([tot, pd.read_csv(file_path)])
    # tot.to_csv(tdp + '/' + game_id + '/' + game_id + '_total.csv' , index=False)

# %%
import pandas as pd

data_path = '../data/phase_baseline_submit.csv'
df = pd.read_csv(data_path)
df= df.dropna()
df.to_csv('./check_base.csv', index=False)
# print(len(df))
# for row in df.iterrows():
#     print(row[1].end_x)
